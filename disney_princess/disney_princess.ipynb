# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('./data/disney_princess_popularity_dataset_300_rows.csv')

# %%
data.head()
# Out:
#   PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0   Pocahontas  Pocahontas's Adventure            1977                   85
# 1        Mulan       Mulan's Adventure            1995                   85
# 2         Raya        Raya's Adventure            1989                  110
# 3         Anna        Anna's Adventure            1940                   78
# 4        Mulan       Mulan's Adventure            1943                  103
#
#    NumberOfSongs HasSoloSong HasDuet HairColor EyeColor OutfitPrimaryColor  \
# 0              4          No     Yes     Brown    Green               Pink
# 1              1         Yes     Yes    Blonde    Brown             Purple
# 2              4          No      No    Blonde    Hazel               Pink
# 3              1          No      No     Brown     Grey              Green
# 4              7          No     Yes     White    Brown              Green
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PrincessName                300 non-null    object
#  1   FirstMovieTitle             300 non-null    object
#  2   FirstMovieYear              300 non-null    int64
#  3   MovieRuntimeMinutes         300 non-null    int64
#  4   NumberOfSongs               300 non-null    int64
#  5   HasSoloSong                 300 non-null    object
#  6   HasDuet                     300 non-null    object
#  7   HairColor                   300 non-null    object
#  8   EyeColor                    300 non-null    object
#  9   OutfitPrimaryColor          300 non-null    object
#  10  OutfitStyleEra              300 non-null    object
#  11  IsRoyalByBirth              300 non-null    object
#  12  HasAnimalSidekick           300 non-null    object
# ...

# %%
data.shape
# Out:
# (300, 36)

# %%
data.isnull().sum()
# Out:
# PrincessName                   0
# FirstMovieTitle                0
# FirstMovieYear                 0
# MovieRuntimeMinutes            0
# NumberOfSongs                  0
# HasSoloSong                    0
# HasDuet                        0
# HairColor                      0
# EyeColor                       0
# OutfitPrimaryColor             0
# OutfitStyleEra                 0
# IsRoyalByBirth                 0
# HasAnimalSidekick              0
# SidekickType                  70
# HasMagicalPowers               0
# MagicType                     53
# MainSetting                    0
# IsBasedOnRealStory             0
# CulturalOrigin                 0
# SpeaksToAnimals                0
# FightsVillainDirectly          0
# RomanticSubplot                0
# MarriedByEnd                   0
# VillainName                    0
# VillainType                   47
# IMDB_Rating                    0
# RottenTomatoesScore            0
# BoxOfficeMillions              0
# ...

# %%
top_10 = data\
    .sort_values(by='PopularityScore', ascending=False)\
    .drop_duplicates(subset='PrincessName', keep='first')

top_10
# Out:
#     PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 72         Moana       Moana's Adventure            1968                   80
# 108        Tiana       Tiana's Adventure            1963                   88
# 129        Ariel       Ariel's Adventure            1977                   80
# 277       Aurora      Aurora's Adventure            1997                  109
# 276        Mulan       Mulan's Adventure            1994                   98
# 61        Merida      Merida's Adventure            1953                   83
# 271   Pocahontas  Pocahontas's Adventure            2009                   98
# 191         Raya        Raya's Adventure            2000                   84
# 126     Rapunzel    Rapunzel's Adventure            2017                   77
# 114   Snow White  Snow White's Adventure            1953                   94
# 244         Elsa        Elsa's Adventure            2007                   71
# ...

# %%
plt.figure(figsize = (10,6))
sns.histplot(data['MovieRuntimeMinutes'], kde=True, color='skyblue')
plt.title('Movie Runtime')
# Out:
# Text(0.5, 1.0, 'Movie Runtime')

# %%
unique_princess = data.drop_duplicates(subset='PrincessName')
unique_princess.head()

plt.figure(figsize = (10,6))
sns.countplot(y='HairColor', data=unique_princess, order=unique_princess['HairColor'].value_counts().index, hue='HairColor', palette='pastel', legend=False)
hair_color_groups = unique_princess.groupby('HairColor')['PrincessName'].apply(list)

# Print nicely
for color, princesses in hair_color_groups.items():
    print(f"{color}: {princesses}")
# Out:
# Black: ['Rapunzel', 'Tiana']
# Blonde: ['Mulan', 'Raya', 'Snow White', 'Ariel', 'Aurora']
# Brown: ['Pocahontas', 'Anna', 'Jasmine', 'Merida']
# Red: ['Belle', 'Cinderella', 'Elsa', 'Moana']
